# %%
import pandas as pd
import nltk
from hazm import word_tokenize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[57], line 3
#       1 import pandas as pd
#       2 import nltk
# ----> 3 from hazm import word_tokenize
#
# ModuleNotFoundError: No module named 'hazm'

# %%
data = pd.read_csv('./per.csv')

# %%
data.head()
# Out:
#    NewsID                                              Title  \
# 0  843656  \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# 1  837144  \nگردهمايي دانش‌آموختگان موسسه آموزش عالي سوره...
# 2  436862  \nنتايج آزمون دوره‌هاي فراگير دانشگاه پيام‌نور...
# 3  227781  \nهمايش يكروزه آسيب شناسي مفهوم روابط عمومي در...
# 4  174187  \nوضعيت اقتصادي و ميزان تحصيلات والدين از مهمت...
#
#                                                 Body         Date       Time  \
# 0  \nوزير علوم در جمع استادان نمونه كشور گفت: از ...  \n138/5//09  \n0:9::18
# 1  \nبه گزارش سرويس صنفي آموزشي خبرگزاري دانشجويا...  \n138/5//09  \n1:4::11
# 2  \nنتايج آزمون دوره‌هاي فراگير مقاطع كارشناسي و...  \n138/3//07  \n1:0::03
# 3                                                 \n  \n138/2//02  \n1:3::42
# 4  \nمحمدتقي علوي يزدي، مجري اين طرح پژوهشي در اي...  \n138/1//08  \n1:1::49
#
#              Category  Category2
# 0           \nآموزشي-   \nآموزشي
# 1           \nآموزشي-   \nآموزشي
# ...

# %%
data.iloc[0 , :]
# Out:
# NewsID                                                  843656
# Title        \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# Body         \nوزير علوم در جمع استادان نمونه كشور گفت: از ...
# Date                                               \n138/5//09
# Time                                                 \n0:9::18
# Category                                             \nآموزشي-
# Category2                                             \nآموزشي
# Name: 0, dtype: object

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\No1\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
stopwords
# Out:
# <WordListCorpusReader in 'C:\\Users\\No1\\AppData\\Roaming\\nltk_data\\corpora\\stopwords'>

# %%
stop = set(stopwords.words('english'))

# %%
with open('./stopwords.txt', 'r') as file :
    stop_words = file.readlines()

# %%
print(stop)
# Out:
# {'she', 'ourselves', "isn't", "it's", 'had', 'if', 'when', 'couldn', 'who', 'will', 'very', 'out', 're', "haven't", 'that', 'here', 'needn', 'o', 'isn', 'our', 'ours', 'such', 'a', 'because', 'mightn', 'them', 'being', 'nor', 'as', 'during', 'there', 'yourselves', 'yours', "shouldn't", 'am', 'can', 'weren', 'while', 'did', 'no', 'over', 'so', 'are', 'it', 'where', 've', 'ma', 'by', 't', 'doing', 'for', 'other', "that'll", 'all', 'through', 'what', 'you', 'on', 'hers', 'herself', 'been', 'does', 'than', 'why', 'myself', 'wasn', 'll', 'before', 'were', 'those', 'his', 'ain', 'few', 'should', 'their', 'its', 'between', 'off', 'is', 'hadn', 'be', 'mustn', 'i', 'same', 'y', 'we', 'itself', 'just', 'into', "didn't", 'her', 'both', 'won', 'he', "doesn't", "couldn't", 'these', "she's", 'once', 'aren', 'himself', 'only', 'after', 'didn', "you'd", 'up', "shan't", "you're", 'themselves', 'about', 'own', 'an', 'now', "weren't", "wouldn't", 'your', 'was', 'yourself', 'me', 'further', 'each', 'hav
# ...

# %%
stop_words
# Out:
# ['!\n',
#  '"\n',
#  '#\n',
#  '(\n',
#  ')\n',
#  '*\n',
#  ',\n',
#  '-\n',
#  '.\n',
#  '/\n',
#  ':\n',
#  '[\n',
#  ']\n',
#  '«\n',
#  '»\n',
#  '،\n',
#  '؛\n',
#  '؟\n',
#  'آباد\n',
#  'آخ\n',
#  'آخر\n',
#  'آخرها\n',
#  'آخه\n',
#  'آدمهاست\n',
#  'آرام\n',
#  'آرام آرام\n',
#  'آره\n',
#  'آری\n',
#  'آزادانه\n',
#  'آسان\n',
#  'آسیب پذیرند\n',
#  'آشنایند\n',
#  'آشکارا\n',
#  'آقا\n',
#  'آقای\n',
#  'آقایان\n',
#  'آمد\n',
#  'آمدن\n',
#  'آمده\n',
#  'آمرانه\n',
#  'آن\n',
#  'آن گاه\n',
#  'آنان\n',
#  'آنانی\n',
#  'آنجا\n',
#  'آنرا\n',
#  'آنطور\n',
#  'آنقدر\n',
#  'آنها\n',
#  'آنهاست\n',
#  'آنچنان\n',
#  'آنچنان که\n',
#  'آنچه\n',
#  'آنکه\n',
#  'آنگاه\n',
#  'آن\u200cها\n',
#  'آهان\n',
#  'آهای\n',
#  'آور\n',
#  'آورد\n',
#  'آوردن\n',
#  'آورده\n',
#  'آوه\n',
#  'آی\n',
#  'آیا\n',
#  'آید\n',
#  'آیند\n',
#  'ا\n',
#  'اتفاقا\n',
#  'اثرِ\n',
#  'اجراست\n',
#  'احتراما\n',
#  'احتمالا\n',
#  'احیاناً\n',
#  'اخیر\n',
#  'اخیراً\n',
#  'اری\n',
# ...

# %%
stop_words = [stop_word.replace('\n', '') for stop_word in stop_words]

# %%
stop_words
# Out:
# ['!',
#  '"',
#  '#',
#  '(',
#  ')',
#  '*',
#  ',',
#  '-',
#  '.',
#  '/',
#  ':',
#  '[',
#  ']',
#  '«',
#  '»',
#  '،',
#  '؛',
#  '؟',
#  'آباد',
#  'آخ',
#  'آخر',
#  'آخرها',
#  'آخه',
#  'آدمهاست',
#  'آرام',
#  'آرام آرام',
#  'آره',
#  'آری',
#  'آزادانه',
#  'آسان',
#  'آسیب پذیرند',
#  'آشنایند',
#  'آشکارا',
#  'آقا',
#  'آقای',
#  'آقایان',
#  'آمد',
#  'آمدن',
#  'آمده',
#  'آمرانه',
#  'آن',
#  'آن گاه',
#  'آنان',
#  'آنانی',
#  'آنجا',
#  'آنرا',
#  'آنطور',
#  'آنقدر',
#  'آنها',
#  'آنهاست',
#  'آنچنان',
#  'آنچنان که',
#  'آنچه',
#  'آنکه',
#  'آنگاه',
#  'آن\u200cها',
#  'آهان',
#  'آهای',
#  'آور',
#  'آورد',
#  'آوردن',
#  'آورده',
#  'آوه',
#  'آی',
#  'آیا',
#  'آید',
#  'آیند',
#  'ا',
#  'اتفاقا',
#  'اثرِ',
#  'اجراست',
#  'احتراما',
#  'احتمالا',
#  'احیاناً',
#  'اخیر',
#  'اخیراً',
#  'اری',
#  'از',
#  'از آن پس',
#  'از جمله',
#  'ازاین رو',
#  'ازجمله',
#  'ازش',
#  'اساسا',
#  'اساساً',
#  'است',
#  'استفاد',
#  'استفاده',
#  'اسلامی اند',
# ...

# %%
stopWords = set(stopwords.words('english'))

datas = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
words = word_tokenize(data)
wordsFiltered = [w for w in words if w not in stopWords]
print(wordsFiltered)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[53], line 4
#       1 stopWords = set(stopwords.words('english'))
#       3 datas = "All work and no play makes jack dull boy. All work and no play makes jack a dull boy."
# ----> 4 words = word_tokenize(data)
#       5 wordsFiltered = [w for w in words if w not in stopWords]
#       6 print(wordsFiltered)
#
# File c:\Users\No1\.conda\envs\myenv\Lib\site-packages\nltk\tokenize\__init__.py:142, in word_tokenize(text, language, preserve_line)
#     127 def word_tokenize(text, language="english", preserve_line=False):
#     128     """
#     129     Return a tokenized copy of *text*,
#     130     using NLTK's recommended word tokenizer
#    (...)
#     140     :type preserve_line: bool
#     141     """
# --> 142     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     143     return [
# ...

# %%
clean_data = pd.DataFrame(columns=['Text', 'label'])

# %%
data.head()
# Out:
#    NewsID                                              Title  \
# 0  843656  \nوزير علوم درجمع استادان نمونه: سن بازنشستگي ...
# 1  837144  \nگردهمايي دانش‌آموختگان موسسه آموزش عالي سوره...
# 2  436862  \nنتايج آزمون دوره‌هاي فراگير دانشگاه پيام‌نور...
# 3  227781  \nهمايش يكروزه آسيب شناسي مفهوم روابط عمومي در...
# 4  174187  \nوضعيت اقتصادي و ميزان تحصيلات والدين از مهمت...
#
#                                                 Body         Date       Time  \
# 0  \nوزير علوم در جمع استادان نمونه كشور گفت: از ...  \n138/5//09  \n0:9::18
# 1  \nبه گزارش سرويس صنفي آموزشي خبرگزاري دانشجويا...  \n138/5//09  \n1:4::11
# 2  \nنتايج آزمون دوره‌هاي فراگير مقاطع كارشناسي و...  \n138/3//07  \n1:0::03
# 3                                                 \n  \n138/2//02  \n1:3::42
# 4  \nمحمدتقي علوي يزدي، مجري اين طرح پژوهشي در اي...  \n138/1//08  \n1:1::49
#
#              Category  Category2
# 0           \nآموزشي-   \nآموزشي
# 1           \nآموزشي-   \nآموزشي
# ...

# %%
for index , row in data.iterrows():
    title_body = row['Title'] + row['Body']
    break

# %%
title_body
# Out:
# '\nوزير علوم درجمع استادان نمونه: سن بازنشستگي استادان نمونه به 70 سال افزايش مي\u200cيابد دانشگاه بايد مهد چالشهاي گفتماني و خط دهنده و برنامه\u200cريز جريانات سياسي باشد\nوزير علوم در جمع استادان نمونه كشور گفت: از استادان نمونه كشور انتظار مي\u200cرود كه رويكرد دانايي محوري و گفتمان علمي را به عنوان يك بحث فرهنگي در دانشگاهها توسعه و رونق بخشند. به گزارش سرويس صنفي آموزشي خبرگزاري دانشجويان ايران (ايسنا)، دكتر محمد مهدي زاهدي در اولين مجمع عمومي استادان نمونه دانشگاه\u200cهاي سراسر كشور كه در دانشگاه تهران برگزار شد، افزود: توصيه ما در جهت تلاش براي دانايي محوري و توسعه گفتمان علمي به معني عدم تمايل به مباحث سياسي نيست؛ بلكه برعكس، دانشگاه بايد مهد چالشهاي گفتماني باشد ولي اين امر، بدان معني نيست كه دانشگاه، ابزار دست سياسيون قرار بگيرد. وي تأكيد كرد: دانشگاه نه تنها نبايد تحت تأثير القائات سياسي قرار بگيرد؛ بلكه بايد خط دهنده و برنامه\u200cريز جريانات سياسي باشد و مهمترين عنصر پياده شدن اين آرمان، دانشجويان و اعضاي هيات علمي دانشگاهها و در رأس آنها استادان نمونه هستند. وزير علوم 
# ...
