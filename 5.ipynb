# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('./melb_data.csv')

# %%
data.tail()
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 18391       23540  Williamstown  8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown     96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie     17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville       6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville    33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 18391     SP        Greg  26/08/2017       6.8  ...       2.0  1.0       NaN
# 18392     PI     Sweeney  26/08/2017       6.8  ...       1.0  5.0     866.0
# 18393      S  Buckingham  26/08/2017      12.7  ...       3.0  2.0       NaN
# 18394     SP     Village  26/08/2017       6.3  ...       1.0  1.0     362.0
# 18395     VB     Village  26/08/2017       6.3  ...       2.0  2.0       NaN
#
#        BuildingArea  YearBuilt  CouncilArea  Lattitude Longtitude  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
len(data)
# Out:
# 18396

# %%
len(data.columns)
# Out:
# 22

# %%
data['Price'] > 1000
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 18391    True
# 18392    True
# 18393    True
# 18394    True
# 18395    True
# Name: Price, Length: 18396, dtype: bool

# %%
data['Rooms'] >= 3
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4         True
#          ...
# 18391    False
# 18392     True
# 18393     True
# 18394     True
# 18395     True
# Name: Rooms, Length: 18396, dtype: bool

# %%
x = (data['Price'] > 100000) & (data["Rooms"] >= 3)

# %%
data[x]
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price  \
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# 6              11    Abbotsford      124 Yarra St      3    h  1876000.0
# 8              15    Abbotsford  217 Langridge St      3    h  1000000.0
# ...           ...           ...               ...    ...  ...        ...
# 18390       23539  Williamstown       83 Power St      3    h  1170000.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# ...

# %%
x_2 = data['Bathroom'] >= 2

# %%
data[x_2]
# Out:
#        Unnamed: 0        Suburb             Address  Rooms Type      Price  \
# 2               4    Abbotsford        5 Charles St      3    h  1465000.0
# 3               5    Abbotsford    40 Federation La      3    h   850000.0
# 6              11    Abbotsford        124 Yarra St      3    h  1876000.0
# 15             23    Abbotsford  411/8 Grosvenor St      2    u   700000.0
# 16             24    Abbotsford     40 Nicholson St      3    h  1350000.0
# ...           ...           ...                 ...    ...  ...        ...
# 18389       23538  Williamstown       77 Merrett Dr      3    h  1031000.0
# 18390       23539  Williamstown         83 Power St      3    h  1170000.0
# 18391       23540  Williamstown     8/2 Thompson St      2    t   622500.0
# 18393       23544     Yallambie        17 Amaroo Wy      4    h  1100000.0
# 18395       23546    Yarraville       33 Freeman St      4    h  1050000.0
#
# ...

# %%
data.shape
# Out:
# (18396, 22)

# %%
data.count()
# Out:
# Unnamed: 0       18396
# Suburb           18396
# Address          18396
# Rooms            18396
# Type             18396
# Price            18396
# Method           18396
# SellerG          18396
# Date             18396
# Distance         18395
# Postcode         18395
# Bedroom2         14927
# Bathroom         14925
# Car              14820
# Landsize         13603
# BuildingArea      7762
# YearBuilt         8958
# CouncilArea      12233
# Lattitude        15064
# Longtitude       15064
# Regionname       18395
# Propertycount    18395
# dtype: int64

# %%
data['Bathroom']
# Out:
# 0        1.0
# 1        1.0
# 2        2.0
# 3        2.0
# 4        1.0
#         ...
# 18391    2.0
# 18392    1.0
# 18393    3.0
# 18394    1.0
# 18395    2.0
# Name: Bathroom, Length: 18396, dtype: float64

# %%
data.dropna()
# Out:
#        Unnamed: 0        Suburb          Address  Rooms Type      Price  \
# 1               2    Abbotsford  25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford     5 Charles St      3    h  1465000.0
# 4               6    Abbotsford      55a Park St      4    h  1600000.0
# 6              11    Abbotsford     124 Yarra St      3    h  1876000.0
# 7              14    Abbotsford    98 Charles St      2    h  1636000.0
# ...           ...           ...              ...    ...  ...        ...
# 15388       19732    Whittlesea    30 Sherwin St      3    h   601000.0
# 15389       19733  Williamstown      75 Cecil St      3    h  1050000.0
# 15390       19734  Williamstown    2/29 Dover Rd      1    u   385000.0
# 15392       19736       Windsor  201/152 Peel St      2    u   560000.0
# 15395       19739    Yarraville  54 Pentland Pde      6    h  2450000.0
#
#       Method        SellerG        Date  Distance  ...  Bathroom  Car  \
# ...

# %%
len(data.dropna())
# Out:
# 6196

# %%
data.describe()
# Out:
#          Unnamed: 0         Rooms         Price      Distance      Postcode  \
# count  18396.000000  18396.000000  1.839600e+04  18395.000000  18395.000000
# mean   11826.787073      2.935040  1.056697e+06     10.389986   3107.140147
# std     6800.710448      0.958202  6.419217e+05      6.009050     95.000995
# min        1.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     5936.750000      2.000000  6.330000e+05      6.300000   3046.000000
# 50%    11820.500000      3.000000  8.800000e+05      9.700000   3085.000000
# 75%    17734.250000      3.000000  1.302000e+06     13.300000   3149.000000
# max    23546.000000     12.000000  9.000000e+06     48.100000   3978.000000
#
#            Bedroom2      Bathroom           Car       Landsize  BuildingArea  \
# count  14927.000000  14925.000000  14820.000000   13603.000000   7762.000000
# mean       2.913043      1.538492      1.615520     558.116371    151.220219
# ...

# %%
data['Car'].mean()
# Out:
# np.float64(1.6155195681511472)

# %%
data['Rooms'].max()
# Out:
# 12

# %%
data['new-address'] = data['Suburb'] + '-' + data['Address']

# %%
data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  Biggin  3/12/2016       2.5  ...  1.0     202.0           NaN        NaN
# 1  Biggin  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  Biggin  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  Biggin  4/03/2017       2.5  ...  1.0      94.0           NaN        NaN
# 4  Nelson  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
# ...

# %%
data['new-type-room'] = str(data['Rooms']) + data['Type']

# %%
data.head()
# Out:
#    Unnamed: 0      Suburb           Address  Rooms Type      Price Method  \
# 0           1  Abbotsford      85 Turner St      2    h  1480000.0      S
# 1           2  Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2           4  Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3           5  Abbotsford  40 Federation La      3    h   850000.0     PI
# 4           6  Abbotsford       55a Park St      4    h  1600000.0     VB
#
#   SellerG       Date  Distance  ...  Landsize  BuildingArea  YearBuilt  \
# 0  Biggin  3/12/2016       2.5  ...     202.0           NaN        NaN
# 1  Biggin  4/02/2016       2.5  ...     156.0          79.0     1900.0
# 2  Biggin  4/03/2017       2.5  ...     134.0         150.0     1900.0
# 3  Biggin  4/03/2017       2.5  ...      94.0           NaN        NaN
# 4  Nelson  4/06/2016       2.5  ...     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname Propertycount  \
# ...

# %%
data['Type'].unique()
# Out:
# array(['h', 't', 'u'], dtype=object)

# %%
data['Type'].value_counts()
# Out:
# Type
# h    12095
# u     4296
# t     2005
# Name: count, dtype: int64

# %%
data[data['Bathroom'] >= 3 ]['Price'].mean()
# Out:
# np.float64(1874205.3619210979)

# %%
data[data['Car'] == 2] ['Price'].min()
# Out:
# 131000.0

# %%
data.groupby('Car')['Price'].min()
# Out:
# Car
# 0.0       85000.0
# 1.0      145000.0
# 2.0      131000.0
# 3.0      370000.0
# 4.0      295000.0
# 5.0      531000.0
# 6.0      451000.0
# 7.0      560000.0
# 8.0      580000.0
# 9.0     2100000.0
# 10.0     880000.0
# Name: Price, dtype: float64

# %%
data.groupby('Type')['Price'].min()
# Out:
# Type
# h    131000.0
# t    256000.0
# u     85000.0
# Name: Price, dtype: float64

# %%
data.groupby('Type')['Car'].max()
# Out:
# Type
# h    10.0
# t     5.0
# u     7.0
# Name: Car, dtype: float64

# %%
data.groupby('Bathroom')['Price'].mean()
# Out:
# Bathroom
# 0.0    8.945588e+05
# 1.0    8.521918e+05
# 2.0    1.216328e+06
# 3.0    1.752052e+06
# 4.0    2.676766e+06
# 5.0    2.720067e+06
# 6.0    2.786200e+06
# 7.0    3.425000e+06
# 8.0    1.480000e+06
# Name: Price, dtype: float64
